# %% [markdown]
# <a href="https://colab.research.google.com/github/asralbum07-ui/asif/blob/main/Calculate%20the%20receptive%20fields.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter the numbers :"))
s=0
while(n!=0):
  p=n%10
  s=s+p
  n=n//10
print("sum number is :",s)
# Out:
# Enter the numbers :123
# sum number is : 6

# %%
n=int(input("Enter the number to reverse :"))
rev=0
num=n
while(n!=0):
  p=n%10
  rev=rev*10+p
  n=n//10
  rev=reversed

  if(rev==s):
    print("the number is palindrome")
  else:
      print("the number is palindrome")

# %%
n=int(input("A number from user to count"))
c=0
while(n!=0):
  p=n%10
  c=c+1
  n=n//10
print("total number of digits :",c)

# %%
n=int(input("A number from user to count"))
c=0
while(n!=0):
  p=n%10
  c=c+1
  n=n//10+p

print("total number of digits :",c)
# Out:
# A number from user to count1234

# %%
n=int(input("Number from user to check number is GCD or LCM"))
